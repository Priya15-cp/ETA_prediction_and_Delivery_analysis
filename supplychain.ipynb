# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
#cleaning time_taken column
df['Time_taken(min)'] = df['Time_taken(min)'].str.replace(r'\(min\) ', '', regex=True).astype(int)
df['Time_taken(min)']
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45588    32
# 45589    36
# 45590    16
# 45591    26
# 45592    36
# Name: Time_taken(min), Length: 45593, dtype: int64

# %%
df['Weatherconditions'] = df['Weatherconditions'].str.replace('conditions', '')
df['Weatherconditions']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15916\572853615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weatherconditions'] = df['Weatherconditions'].str.replace('conditions', '')
# 0             s Sunny
# 1            s Stormy
# 2        s Sandstorms
# 3             s Sunny
# 4            s Cloudy
#              ...
# 45588         s Windy
# 45589         s Windy
# 45590        s Cloudy
# 45591        s Cloudy
# 45592           s Fog
# Name: Weatherconditions, Length: 43685, dtype: object

# %%
df['Road_traffic_density'] = df['Road_traffic_density'].str.strip()
df['Road_traffic_density']
# Out:
# 0          High
# 1           Jam
# 2           Low
# 3        Medium
# 4          High
#           ...
# 45588      High
# 45589       Jam
# 45590       Low
# 45591      High
# 45592    Medium
# Name: Road_traffic_density, Length: 45593, dtype: object

# %%
df['Delivery_person_Age'] = pd.to_numeric(df['Delivery_person_Age'], errors='coerce')
df['Delivery_person_Age']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15916\1593586470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_person_Age'] = pd.to_numeric(df['Delivery_person_Age'], errors='coerce')
# 0        37.0
# 1        34.0
# 2        23.0
# 3        38.0
# 4        32.0
#          ...
# 45588    30.0
# 45589    21.0
# 45590    30.0
# 45591    20.0
# 45592    23.0
# Name: Delivery_person_Age, Length: 43685, dtype: float64

# %%
df['Delivery_person_Ratings']= pd.to_numeric(df['Delivery_person_Ratings'],errors = 'coerce')
df['Delivery_person_Ratings']
# Out:
# 0        4.9
# 1        4.5
# 2        4.4
# 3        4.7
# 4        4.6
#         ...
# 45588    4.8
# 45589    4.6
# 45590    4.9
# 45591    4.7
# 45592    4.9
# Name: Delivery_person_Ratings, Length: 45593, dtype: float64

# %%
df = df.replace('NaN', 'np.nan')
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                  37.0
# 1      0xb379     BANGRES18DEL02                  34.0
# 2      0x5d6d     BANGRES19DEL01                  23.0
# 3      0x7a6a    COIMBRES13DEL02                  38.0
# 4      0x70a2     CHENRES12DEL01                  32.0
# ...        ...                ...                  ...
# 45588  0x7c09      JAPRES04DEL01                  30.0
# 45589  0xd641      AGRRES16DEL01                  21.0
# 45590  0x4f8d     CHENRES08DEL03                  30.0
# 45591  0x5eee    COIMBRES11DEL01                  20.0
# 45592  0x5fb2   RANCHIRES09DEL02                  23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# ...

# %%
d=df = df.dropna()
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                  37.0
# 1      0xb379     BANGRES18DEL02                  34.0
# 2      0x5d6d     BANGRES19DEL01                  23.0
# 3      0x7a6a    COIMBRES13DEL02                  38.0
# 4      0x70a2     CHENRES12DEL01                  32.0
# ...        ...                ...                  ...
# 45588  0x7c09      JAPRES04DEL01                  30.0
# 45589  0xd641      AGRRES16DEL01                  21.0
# 45590  0x4f8d     CHENRES08DEL03                  30.0
# 45591  0x5eee    COIMBRES11DEL01                  20.0
# 45592  0x5fb2   RANCHIRES09DEL02                  23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# ...

# %%
print(df['Time_taken(min)'].dtype)
# Out:
# int64

# %%
print(df['Weatherconditions'].unique())
# Out:
# ['s Sunny' 's Stormy' 's Sandstorms' 's Cloudy' 's Fog' 's Windy' 's NaN']

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
